# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests as req
from datetime import datetime
import time
from scipy.stats import linregress
from anna import *
# Import the API key.
from config import weather_api_key

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
coords = [(i,j) for i in np.random.uniform(low=-90.000, high=90.000, size=50)
          for j in np.random.uniform(low=-90.000, high=90.000, size=50)]

# %%
len(coords)
# Out:
# 2500

# %%
# Identify the nearest city for each latitude and longitude combination.
cities = list({citipy.nearest_city(i[0], i[1]).city_name for i in coords})

# %%
len(cities)
# Out:
# 781

# %%
# Starting URL for Weather Map API Call.
url = 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=' + weather_api_key

# %%
city_url = url + '&q=' + 'aswan' #city.replace(" ","+")

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = req.get(city_url).json()
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        current = city_weather['weather'][0]['description']
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                        "Country": city_country,
                        "Lat": city_lat,
                        "Lng": city_lng,
                        "Max Temp": city_max_temp,
                        "Humidity": city_humidity,
                        "Cloudiness": city_clouds,
                        "Wind Speed": city_wind,
                        "Current Description": current})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | aswan
# Processing Record 2 of Set 1 | berlevag
# Processing Record 3 of Set 1 | puerto lempira
# Processing Record 4 of Set 1 | pedra azul
# Processing Record 5 of Set 1 | saint-augustin
# Processing Record 6 of Set 1 | synya
# Processing Record 7 of Set 1 | svetlyy
# Processing Record 8 of Set 1 | khislavichi
# Processing Record 9 of Set 1 | totness
# Processing Record 10 of Set 1 | bagotville
# Processing Record 11 of Set 1 | poretskoye
# Processing Record 12 of Set 1 | kerman
# Processing Record 13 of Set 1 | rockland
# Processing Record 14 of Set 1 | aulnoye-aymeries
# Processing Record 15 of Set 1 | comodoro rivadavia
# Processing Record 16 of Set 1 | yekimovichi
# Processing Record 17 of Set 1 | kalaleh
# Processing Record 18 of Set 1 | epe
# Processing Record 19 of Set 1 | kaunas
# Processing Record 20 of Set 1 | daphne
# Processing Record 21 of Set 1 | los llanos de aridane
# Processing Record 22 of Set 1 | erie
# Processing Record 23 of Set 1 | rundu
# Processing Record 24 of Set 1 | police
# Processing Record 25 of Set 1 | kharitonovo
# Processing Record 26 of Set 1 | bulaevo
# Processing Record 27 of Set 1 | janauba
# Processing Record 28 of Set 1 | aktau
# Processing Record 29 of Set 1 | strezhevoy
# Processing Record 30 of Set 1 | hofn
# Processing Record 31 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 32 of Set 1 | honningsvag
# Processing Record 33 of Set 1 | brae
# Processing Record 34 of Set 1 | saint-francois
# Processing Record 35 of Set 1 | toamasina
# Processing Record 36 of Set 1 | mananara
# Processing Record 37 of Set 1 | lasa
# Processing Record 38 of Set 1 | nueva imperial
# Processing Record 39 of Set 1 | barybino
# Processing Record 40 of Set 1 | camapua
# Processing Record 41 of Set 1 | aleksandrov gay
# Processing Record 42 of Set 1 | goryachegorsk
# Processing Record 43 of Set 1 | necochea
# Processing Record 44 of Set 1 | nuuk
# Processing Record 45 of Set 1 | ozgon
# City not found. Skipping...
# Processing Record 46 of Set 1 | bastia
# Processing Record 47 of Set 1 | pisticci
# Processing Record 48 of Set 1 | mariel
# Processing Record 49 of Set 1 | podyuga
# Processing Record 50 of Set 1 | jaragua
# Processing Record 1 of Set 2 | cerkezkoy
# Processing Record 2 of Set 2 | knurow
# Processing Record 3 of Set 2 | abu dhabi
# Processing Record 4 of Set 2 | aflu
# City not found. Skipping...
# Processing Record 5 of Set 2 | sirmaur
# Processing Record 6 of Set 2 | pervomayskoye
# Processing Record 7 of Set 2 | jalu
# Processing Record 8 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 2 | barela
# Processing Record 10 of Set 2 | hithadhoo
# Processing Record 11 of Set 2 | malwan
# City not found. Skipping...
# Processing Record 12 of Set 2 | suaita
# Processing Record 13 of Set 2 | sandane
# Processing Record 14 of Set 2 | khvastovichi
# Processing Record 15 of Set 2 | moratuwa
# Processing Record 16 of Set 2 | ivybridge
# Processing Record 17 of Set 2 | sernovodsk
# Processing Record 18 of Set 2 | mizan teferi
# Processing Record 19 of Set 2 | goias
# Processing Record 20 of Set 2 | ugra
# Processing Record 21 of Set 2 | chhatarpur
# Processing Record 22 of Set 2 | nassjo
# Processing Record 23 of Set 2 | gazojak
# Processing Record 24 of Set 2 | longlac
# City not found. Skipping...
# Processing Record 25 of Set 2 | mahajanga
# Processing Record 26 of Set 2 | port hawkesbury
# Processing Record 27 of Set 2 | gurgan
# City not found. Skipping...
# Processing Record 28 of Set 2 | puerto madryn
# Processing Record 29 of Set 2 | fecamp
# Processing Record 30 of Set 2 | morondava
# Processing Record 31 of Set 2 | mercedes
# Processing Record 32 of Set 2 | treuchtlingen
# Processing Record 33 of Set 2 | sept-iles
# Processing Record 34 of Set 2 | busselton
# Processing Record 35 of Set 2 | kurchum
# Processing Record 36 of Set 2 | uren
# Processing Record 37 of Set 2 | ust-shonosha
# Processing Record 38 of Set 2 | nouadhibou
# Processing Record 39 of Set 2 | zhezkazgan
# Processing Record 40 of Set 2 | angra
# City not found. Skipping...
# Processing Record 41 of Set 2 | ginir
# Processing Record 42 of Set 2 | fernandina beach
# Processing Record 43 of Set 2 | progreso
# Processing Record 44 of Set 2 | donskoye
# Processing Record 45 of Set 2 | chabahar
# Processing Record 46 of Set 2 | hamilton
# Processing Record 47 of Set 2 | viterbo
# Processing Record 48 of Set 2 | moengo
# Processing Record 49 of Set 2 | saldanha
# Processing Record 50 of Set 2 | cap-aux-meules
# Processing Record 1 of Set 3 | road town
# Processing Record 2 of Set 3 | mirzapur
# Processing Record 3 of Set 3 | dalvik
# Processing Record 4 of Set 3 | quelimane
# Processing Record 5 of Set 3 | rawatbhata
# Processing Record 6 of Set 3 | horasan
# Processing Record 7 of Set 3 | onega
# Processing Record 8 of Set 3 | ruwi
# Processing Record 9 of Set 3 | geraldton
# Processing Record 10 of Set 3 | goure
# Processing Record 11 of Set 3 | grand gaube
# Processing Record 12 of Set 3 | tatawin
# Processing Record 13 of Set 3 | thompson
# Processing Record 14 of Set 3 | jonava
# Processing Record 15 of Set 3 | bahia blanca
# Processing Record 16 of Set 3 | dustlik
# Processing Record 17 of Set 3 | aurich
# Processing Record 18 of Set 3 | narsaq
# Processing Record 19 of Set 3 | bakal
# Processing Record 20 of Set 3 | saint-pierre
# Processing Record 21 of Set 3 | port elizabeth
# Processing Record 22 of Set 3 | navalcarnero
# Processing Record 23 of Set 3 | bouca
# Processing Record 24 of Set 3 | sarai
# Processing Record 25 of Set 3 | murrhardt
# Processing Record 26 of Set 3 | hobyo
# Processing Record 27 of Set 3 | decatur
# Processing Record 28 of Set 3 | saryagash
# Processing Record 29 of Set 3 | dingle
# Processing Record 30 of Set 3 | baghdad
# Processing Record 31 of Set 3 | eregli
# Processing Record 32 of Set 3 | luangwa
# Processing Record 33 of Set 3 | listvyagi
# Processing Record 34 of Set 3 | sergeyevka
# Processing Record 35 of Set 3 | harvard
# Processing Record 36 of Set 3 | asfi
# Processing Record 37 of Set 3 | colonia
# Processing Record 38 of Set 3 | dakar
# Processing Record 39 of Set 3 | arinos
# Processing Record 40 of Set 3 | orel-izumrud
# Processing Record 41 of Set 3 | nanortalik
# Processing Record 42 of Set 3 | middletown
# Processing Record 43 of Set 3 | bytosh
# Processing Record 44 of Set 3 | peniche
# Processing Record 45 of Set 3 | jumla
# Processing Record 46 of Set 3 | inegol
# Processing Record 47 of Set 3 | mahebourg
# Processing Record 48 of Set 3 | akcakoca
# Processing Record 49 of Set 3 | normandin
# Processing Record 50 of Set 3 | lluta
# Processing Record 1 of Set 4 | sohag
# Processing Record 2 of Set 4 | chardara
# Processing Record 3 of Set 4 | puerto carreno
# Processing Record 4 of Set 4 | paamiut
# Processing Record 5 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 6 of Set 4 | mangrol
# Processing Record 7 of Set 4 | sobreira
# Processing Record 8 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 9 of Set 4 | monze
# Processing Record 10 of Set 4 | macedo de cavaleiros
# Processing Record 11 of Set 4 | busayra
# Processing Record 12 of Set 4 | oneonta
# Processing Record 13 of Set 4 | peachtree city
# Processing Record 14 of Set 4 | lorca
# Processing Record 15 of Set 4 | kjustendil
# Processing Record 16 of Set 4 | novyy urengoy
# Processing Record 17 of Set 4 | ajdabiya
# Processing Record 18 of Set 4 | veliki trnovac
# Processing Record 19 of Set 4 | harnosand
# Processing Record 20 of Set 4 | qaanaaq
# Processing Record 21 of Set 4 | ovre ardal
# Processing Record 22 of Set 4 | douentza
# Processing Record 23 of Set 4 | ptghni
# Processing Record 24 of Set 4 | proletarskiy
# Processing Record 25 of Set 4 | chaman
# Processing Record 26 of Set 4 | rognan
# Processing Record 27 of Set 4 | loukhi
# Processing Record 28 of Set 4 | sanary-sur-mer
# Processing Record 29 of Set 4 | marrakesh
# Processing Record 30 of Set 4 | farakka
# Processing Record 31 of Set 4 | rudozem
# Processing Record 32 of Set 4 | bambous virieux
# Processing Record 33 of Set 4 | obninsk
# Processing Record 34 of Set 4 | khabary
# Processing Record 35 of Set 4 | torrevieja
# Processing Record 36 of Set 4 | san jose
# Processing Record 37 of Set 4 | bonavista
# Processing Record 38 of Set 4 | talcahuano
# Processing Record 39 of Set 4 | sungurlu
# Processing Record 40 of Set 4 | guiratinga
# Processing Record 41 of Set 4 | monte carmelo
# Processing Record 42 of Set 4 | sinop
# Processing Record 43 of Set 4 | yantarnyy
# Processing Record 44 of Set 4 | brindisi
# Processing Record 45 of Set 4 | pisco
# Processing Record 46 of Set 4 | maloyaz
# City not found. Skipping...
# Processing Record 47 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 48 of Set 4 | caceres
# Processing Record 49 of Set 4 | diffa
# Processing Record 50 of Set 4 | aksarka
# Processing Record 1 of Set 5 | mascote
# Processing Record 2 of Set 5 | quirinopolis
# Processing Record 3 of Set 5 | awjilah
# Processing Record 4 of Set 5 | at-bashi
# Processing Record 5 of Set 5 | kasimov
# Processing Record 6 of Set 5 | sisimiut
# Processing Record 7 of Set 5 | ozerki
# Processing Record 8 of Set 5 | ugoofaaru
# Processing Record 9 of Set 5 | bahia honda
# Processing Record 10 of Set 5 | zaragoza
# Processing Record 11 of Set 5 | zlocieniec
# Processing Record 12 of Set 5 | termoli
# Processing Record 13 of Set 5 | uthal
# Processing Record 14 of Set 5 | jamestown
# Processing Record 15 of Set 5 | vila franca do campo
# Processing Record 16 of Set 5 | rieti
# Processing Record 17 of Set 5 | nassau
# Processing Record 18 of Set 5 | salalah
# Processing Record 19 of Set 5 | beyneu
# Processing Record 20 of Set 5 | agva
# City not found. Skipping...
# Processing Record 21 of Set 5 | moskovskiy
# Processing Record 22 of Set 5 | zverinogolovskoye
# Processing Record 23 of Set 5 | slavonice
# Processing Record 24 of Set 5 | henderson
# Processing Record 25 of Set 5 | mahon
# Processing Record 26 of Set 5 | waycross
# Processing Record 27 of Set 5 | marlborough
# Processing Record 28 of Set 5 | brewster
# Processing Record 29 of Set 5 | yar-sale
# Processing Record 30 of Set 5 | arona
# Processing Record 31 of Set 5 | wilmington
# Processing Record 32 of Set 5 | olean
# Processing Record 33 of Set 5 | nikolsk
# Processing Record 34 of Set 5 | bandarbeyla
# Processing Record 35 of Set 5 | santo antonio do leverger
# Processing Record 36 of Set 5 | liverpool
# Processing Record 37 of Set 5 | cap malheureux
# Processing Record 38 of Set 5 | alcaniz
# Processing Record 39 of Set 5 | paramaribo
# Processing Record 40 of Set 5 | kamenka
# Processing Record 41 of Set 5 | mattru
# Processing Record 42 of Set 5 | seydi
# Processing Record 43 of Set 5 | chesma
# Processing Record 44 of Set 5 | kajaani
# Processing Record 45 of Set 5 | aksu
# Processing Record 46 of Set 5 | huarmey
# Processing Record 47 of Set 5 | andros town
# Processing Record 48 of Set 5 | mursalimkino
# Processing Record 49 of Set 5 | alexandria
# Processing Record 50 of Set 5 | tara
# Processing Record 1 of Set 6 | tasiilaq
# Processing Record 2 of Set 6 | tiznit
# Processing Record 3 of Set 6 | svencionys
# Processing Record 4 of Set 6 | baran
# Processing Record 5 of Set 6 | peski
# Processing Record 6 of Set 6 | ondjiva
# Processing Record 7 of Set 6 | cape town
# Processing Record 8 of Set 6 | porto novo
# Processing Record 9 of Set 6 | tikamgarh
# Processing Record 10 of Set 6 | mugur-aksy
# Processing Record 11 of Set 6 | heinola
# Processing Record 12 of Set 6 | sharan
# Processing Record 13 of Set 6 | kommunisticheskiy
# Processing Record 14 of Set 6 | pasni
# Processing Record 15 of Set 6 | kyzyl-suu
# Processing Record 16 of Set 6 | savinka
# Processing Record 17 of Set 6 | zachagansk
# City not found. Skipping...
# Processing Record 18 of Set 6 | san carlos de bariloche
# Processing Record 19 of Set 6 | trud
# Processing Record 20 of Set 6 | polunochnoye
# Processing Record 21 of Set 6 | bathsheba
# Processing Record 22 of Set 6 | vranjska banja
# Processing Record 23 of Set 6 | maryanovka
# City not found. Skipping...
# Processing Record 24 of Set 6 | sile
# Processing Record 25 of Set 6 | teya
# Processing Record 26 of Set 6 | pangnirtung
# Processing Record 27 of Set 6 | belmonte
# Processing Record 28 of Set 6 | ormara
# Processing Record 29 of Set 6 | jackson
# Processing Record 30 of Set 6 | cockburn town
# Processing Record 31 of Set 6 | snina
# Processing Record 32 of Set 6 | lancut
# Processing Record 33 of Set 6 | hammelburg
# Processing Record 34 of Set 6 | altoona
# Processing Record 35 of Set 6 | korla
# Processing Record 36 of Set 6 | key largo
# Processing Record 37 of Set 6 | mar del plata
# Processing Record 38 of Set 6 | jiddah
# City not found. Skipping...
# Processing Record 39 of Set 6 | gibraleon
# Processing Record 40 of Set 6 | riyadh
# Processing Record 41 of Set 6 | leshukonskoye
# Processing Record 42 of Set 6 | muros
# Processing Record 43 of Set 6 | tenenkou
# Processing Record 44 of Set 6 | heywood
# Processing Record 45 of Set 6 | mastic beach
# Processing Record 46 of Set 6 | san joaquin
# Processing Record 47 of Set 6 | salinopolis
# Processing Record 48 of Set 6 | hvammstangi
# City not found. Skipping...
# Processing Record 49 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 6 | nesna
# Processing Record 1 of Set 7 | pasinler
# Processing Record 2 of Set 7 | shubarkuduk
# Processing Record 3 of Set 7 | gornyy
# Processing Record 4 of Set 7 | asyut
# Processing Record 5 of Set 7 | vardo
# Processing Record 6 of Set 7 | newark
# Processing Record 7 of Set 7 | luderitz
# Processing Record 8 of Set 7 | bhinmal
# Processing Record 9 of Set 7 | orangeburg
# Processing Record 10 of Set 7 | hit
# Processing Record 11 of Set 7 | palencia
# Processing Record 12 of Set 7 | abu samrah
# Processing Record 13 of Set 7 | iqaluit
# Processing Record 14 of Set 7 | eyl
# Processing Record 15 of Set 7 | harlingen
# Processing Record 16 of Set 7 | mount pleasant
# Processing Record 17 of Set 7 | sanchor
# Processing Record 18 of Set 7 | saint-ambroise
# Processing Record 19 of Set 7 | ballina
# Processing Record 20 of Set 7 | panjakent
# Processing Record 21 of Set 7 | disna
# Processing Record 22 of Set 7 | penzance
# Processing Record 23 of Set 7 | cine
# Processing Record 24 of Set 7 | jaroslaw
# Processing Record 25 of Set 7 | varhaug
# Processing Record 26 of Set 7 | jhelum
# Processing Record 27 of Set 7 | mizdah
# Processing Record 28 of Set 7 | okoneshnikovo
# Processing Record 29 of Set 7 | biga
# Processing Record 30 of Set 7 | plovdiv
# Processing Record 31 of Set 7 | vadinsk
# Processing Record 32 of Set 7 | georgetown
# Processing Record 33 of Set 7 | ventspils
# Processing Record 34 of Set 7 | muzhi
# Processing Record 35 of Set 7 | tornio
# Processing Record 36 of Set 7 | kargasok
# Processing Record 37 of Set 7 | susehri
# Processing Record 38 of Set 7 | kalmunai
# Processing Record 39 of Set 7 | bengkulu
# Processing Record 40 of Set 7 | hermanus
# Processing Record 41 of Set 7 | clarence town
# Processing Record 42 of Set 7 | saint george
# Processing Record 43 of Set 7 | makat
# Processing Record 44 of Set 7 | anzio
# Processing Record 45 of Set 7 | chittaurgarh
# Processing Record 46 of Set 7 | krasnoarmeysk
# Processing Record 47 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 7 | santiago
# Processing Record 49 of Set 7 | quatre cocos
# Processing Record 50 of Set 7 | eskasem
# City not found. Skipping...
# Processing Record 1 of Set 8 | muscat
# Processing Record 2 of Set 8 | lebu
# Processing Record 3 of Set 8 | adeje
# Processing Record 4 of Set 8 | urbana
# Processing Record 5 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 6 of Set 8 | arnedo
# Processing Record 7 of Set 8 | lebork
# Processing Record 8 of Set 8 | bayir
# Processing Record 9 of Set 8 | kovernino
# Processing Record 10 of Set 8 | kalamazoo
# Processing Record 11 of Set 8 | varnamo
# Processing Record 12 of Set 8 | mocambique
# City not found. Skipping...
# Processing Record 13 of Set 8 | adre
# Processing Record 14 of Set 8 | oni
# Processing Record 15 of Set 8 | marsa matruh
# Processing Record 16 of Set 8 | esna
# Processing Record 17 of Set 8 | shenkursk
# Processing Record 18 of Set 8 | trebinje
# Processing Record 19 of Set 8 | kimovsk
# Processing Record 20 of Set 8 | havelock
# Processing Record 21 of Set 8 | chivay
# Processing Record 22 of Set 8 | xuddur
# Processing Record 23 of Set 8 | hakkari
# Processing Record 24 of Set 8 | camara de lobos
# Processing Record 25 of Set 8 | hwange
# Processing Record 26 of Set 8 | teruel
# Processing Record 27 of Set 8 | llangefni
# Processing Record 28 of Set 8 | novyy buyan
# Processing Record 29 of Set 8 | margate
# Processing Record 30 of Set 8 | rabo de peixe
# Processing Record 31 of Set 8 | lukovetskiy
# Processing Record 32 of Set 8 | mullingar
# Processing Record 33 of Set 8 | monki
# Processing Record 34 of Set 8 | radcliff
# Processing Record 35 of Set 8 | tinos
# Processing Record 36 of Set 8 | krasnoselkup
# Processing Record 37 of Set 8 | upernavik
# Processing Record 38 of Set 8 | dubai
# Processing Record 39 of Set 8 | konevo
# Processing Record 40 of Set 8 | fershampenuaz
# Processing Record 41 of Set 8 | abasha
# Processing Record 42 of Set 8 | castro
# Processing Record 43 of Set 8 | yarmouth
# Processing Record 44 of Set 8 | morshansk
# Processing Record 45 of Set 8 | alcudia
# Processing Record 46 of Set 8 | shache
# Processing Record 47 of Set 8 | mikun
# Processing Record 48 of Set 8 | glyadyanskoye
# Processing Record 49 of Set 8 | tilsonburg
# City not found. Skipping...
# Processing Record 50 of Set 8 | maragogi
# Processing Record 1 of Set 9 | suluktu
# Processing Record 2 of Set 9 | la sarre
# Processing Record 3 of Set 9 | arazede
# Processing Record 4 of Set 9 | isagarh
# Processing Record 5 of Set 9 | marystown
# Processing Record 6 of Set 9 | puerto del rosario
# Processing Record 7 of Set 9 | springdale
# Processing Record 8 of Set 9 | ponta delgada
# Processing Record 9 of Set 9 | golynki
# Processing Record 10 of Set 9 | iralaya
# Processing Record 11 of Set 9 | back mountain
# Processing Record 12 of Set 9 | maniitsoq
# Processing Record 13 of Set 9 | upata
# Processing Record 14 of Set 9 | talesh
# City not found. Skipping...
# Processing Record 15 of Set 9 | sioux lookout
# Processing Record 16 of Set 9 | maldonado
# Processing Record 17 of Set 9 | longyearbyen
# Processing Record 18 of Set 9 | cravo norte
# Processing Record 19 of Set 9 | havoysund
# Processing Record 20 of Set 9 | saint marys
# Processing Record 21 of Set 9 | dikson
# Processing Record 22 of Set 9 | hubli
# Processing Record 23 of Set 9 | plymouth
# Processing Record 24 of Set 9 | maroantsetra
# Processing Record 25 of Set 9 | westport
# Processing Record 26 of Set 9 | hunza
# City not found. Skipping...
# Processing Record 27 of Set 9 | belyy yar
# Processing Record 28 of Set 9 | ponta do sol
# Processing Record 29 of Set 9 | trofors
# Processing Record 30 of Set 9 | ribeira grande
# Processing Record 31 of Set 9 | adrar
# Processing Record 32 of Set 9 | rio gallegos
# Processing Record 33 of Set 9 | biltine
# Processing Record 34 of Set 9 | raudeberg
# Processing Record 35 of Set 9 | senanga
# Processing Record 36 of Set 9 | roald
# Processing Record 37 of Set 9 | letterkenny
# Processing Record 38 of Set 9 | buarcos
# Processing Record 39 of Set 9 | san pedro
# Processing Record 40 of Set 9 | rosetta
# Processing Record 41 of Set 9 | barentsburg
# City not found. Skipping...
# Processing Record 42 of Set 9 | murdochville
# Processing Record 43 of Set 9 | plettenberg bay
# Processing Record 44 of Set 9 | margara
# Processing Record 45 of Set 9 | jardim
# Processing Record 46 of Set 9 | turayf
# Processing Record 47 of Set 9 | zabol
# Processing Record 48 of Set 9 | leh
# Processing Record 49 of Set 9 | ajaccio
# Processing Record 50 of Set 9 | umm lajj
# Processing Record 1 of Set 10 | ginda
# Processing Record 2 of Set 10 | sovetsk
# Processing Record 3 of Set 10 | neubrandenburg
# Processing Record 4 of Set 10 | gustrow
# Processing Record 5 of Set 10 | arica
# Processing Record 6 of Set 10 | bolu
# Processing Record 7 of Set 10 | kalachinsk
# Processing Record 8 of Set 10 | rio grande
# Processing Record 9 of Set 10 | bay roberts
# Processing Record 10 of Set 10 | sukhumi
# Processing Record 11 of Set 10 | zanesville
# Processing Record 12 of Set 10 | aluksne
# Processing Record 13 of Set 10 | tyumen
# Processing Record 14 of Set 10 | agara
# Processing Record 15 of Set 10 | vitina
# Processing Record 16 of Set 10 | glubokoe
# City not found. Skipping...
# Processing Record 17 of Set 10 | naftalan
# Processing Record 18 of Set 10 | blonduos
# City not found. Skipping...
# Processing Record 19 of Set 10 | skegness
# Processing Record 20 of Set 10 | neuquen
# Processing Record 21 of Set 10 | podbelsk
# City not found. Skipping...
# Processing Record 22 of Set 10 | burdur
# Processing Record 23 of Set 10 | kalabo
# Processing Record 24 of Set 10 | chechat
# Processing Record 25 of Set 10 | namibe
# Processing Record 26 of Set 10 | general roca
# Processing Record 27 of Set 10 | gat
# Processing Record 28 of Set 10 | penne
# Processing Record 29 of Set 10 | agadir
# Processing Record 30 of Set 10 | praia da vitoria
# Processing Record 31 of Set 10 | albany
# Processing Record 32 of Set 10 | souillac
# Processing Record 33 of Set 10 | georgiyevka
# Processing Record 34 of Set 10 | lagoa
# Processing Record 35 of Set 10 | bokovskaya
# Processing Record 36 of Set 10 | parrita
# Processing Record 37 of Set 10 | dombarovskiy
# Processing Record 38 of Set 10 | shamary
# Processing Record 39 of Set 10 | sorata
# Processing Record 40 of Set 10 | shakhtinsk
# Processing Record 41 of Set 10 | barra do garcas
# Processing Record 42 of Set 10 | beysehir
# Processing Record 43 of Set 10 | mantua
# Processing Record 44 of Set 10 | turka
# Processing Record 45 of Set 10 | rocha
# Processing Record 46 of Set 10 | umm durman
# City not found. Skipping...
# Processing Record 47 of Set 10 | gwadar
# Processing Record 48 of Set 10 | anar darreh
# City not found. Skipping...
# Processing Record 49 of Set 10 | svarstad
# Processing Record 50 of Set 10 | phalombe
# Processing Record 1 of Set 11 | boddam
# Processing Record 2 of Set 11 | shchuchye
# City not found. Skipping...
# Processing Record 3 of Set 11 | kashi
# Processing Record 4 of Set 11 | san juan
# Processing Record 5 of Set 11 | rantoul
# Processing Record 6 of Set 11 | rorvik
# Processing Record 7 of Set 11 | tarancon
# Processing Record 8 of Set 11 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 11 | mocuba
# Processing Record 10 of Set 11 | dakoro
# Processing Record 11 of Set 11 | kapuskasing
# Processing Record 12 of Set 11 | koryazhma
# Processing Record 13 of Set 11 | vylgort
# City not found. Skipping...
# Processing Record 14 of Set 11 | mehran
# Processing Record 15 of Set 11 | cayenne
# Processing Record 16 of Set 11 | talnakh
# Processing Record 17 of Set 11 | faya
# Processing Record 18 of Set 11 | atar
# Processing Record 19 of Set 11 | sao filipe
# Processing Record 20 of Set 11 | chapais
# Processing Record 21 of Set 11 | chik
# Processing Record 22 of Set 11 | sharjah
# Processing Record 23 of Set 11 | sao joao da barra
# Processing Record 24 of Set 11 | tanout
# Processing Record 25 of Set 11 | lyaskelya
# Processing Record 26 of Set 11 | ilulissat
# Processing Record 27 of Set 11 | emba
# Processing Record 28 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 29 of Set 11 | kazanlak
# Processing Record 30 of Set 11 | codrington
# Processing Record 31 of Set 11 | blantyre
# Processing Record 32 of Set 11 | nukus
# Processing Record 33 of Set 11 | vestmannaeyjar
# Processing Record 34 of Set 11 | pitea
# Processing Record 35 of Set 11 | kungsbacka
# Processing Record 36 of Set 11 | trudarmeyskiy
# Processing Record 37 of Set 11 | bud
# Processing Record 38 of Set 11 | atbasar
# Processing Record 39 of Set 11 | solovetskiy
# City not found. Skipping...
# Processing Record 40 of Set 11 | kiknur
# Processing Record 41 of Set 11 | punta arenas
# Processing Record 42 of Set 11 | tinglev
# Processing Record 43 of Set 11 | krotovka
# Processing Record 44 of Set 11 | godda
# Processing Record 45 of Set 11 | kruisfontein
# Processing Record 46 of Set 11 | izhma
# Processing Record 47 of Set 11 | imisli
# City not found. Skipping...
# Processing Record 48 of Set 11 | turkan
# Processing Record 49 of Set 11 | birjand
# Processing Record 50 of Set 11 | key west
# Processing Record 1 of Set 12 | havre-saint-pierre
# Processing Record 2 of Set 12 | olafsvik
# Processing Record 3 of Set 12 | general pico
# Processing Record 4 of Set 12 | orativ
# Processing Record 5 of Set 12 | svarychiv
# Processing Record 6 of Set 12 | copacabana
# Processing Record 7 of Set 12 | harrisburg
# Processing Record 8 of Set 12 | richmond
# Processing Record 9 of Set 12 | marzuq
# Processing Record 10 of Set 12 | san carlos
# Processing Record 11 of Set 12 | zemio
# Processing Record 12 of Set 12 | charlestown
# Processing Record 13 of Set 12 | xocali
# Processing Record 14 of Set 12 | portpatrick
# City not found. Skipping...
# Processing Record 15 of Set 12 | ornskoldsvik
# Processing Record 16 of Set 12 | sainte-maxime
# Processing Record 17 of Set 12 | krasnyy yar
# Processing Record 18 of Set 12 | vordingborg
# Processing Record 19 of Set 12 | siatista
# Processing Record 20 of Set 12 | carrickfergus
# Processing Record 21 of Set 12 | laguna
# Processing Record 22 of Set 12 | saint anthony
# Processing Record 23 of Set 12 | shar
# Processing Record 24 of Set 12 | oytal
# Processing Record 25 of Set 12 | griffin
# Processing Record 26 of Set 12 | skibbereen
# Processing Record 27 of Set 12 | koslan
# Processing Record 28 of Set 12 | buqayq
# City not found. Skipping...
# Processing Record 29 of Set 12 | fraga
# Processing Record 30 of Set 12 | acari
# Processing Record 31 of Set 12 | nakambala
# Processing Record 32 of Set 12 | marstal
# Processing Record 33 of Set 12 | zliv
# Processing Record 34 of Set 12 | riviere-au-renard
# Processing Record 35 of Set 12 | ust-koksa
# Processing Record 36 of Set 12 | chakia
# Processing Record 37 of Set 12 | taiobeiras
# Processing Record 38 of Set 12 | sterlibashevo
# Processing Record 39 of Set 12 | corning
# Processing Record 40 of Set 12 | brezovo
# Processing Record 41 of Set 12 | qaqortoq
# Processing Record 42 of Set 12 | chhabra
# Processing Record 43 of Set 12 | juybar
# Processing Record 44 of Set 12 | gonbad-e qabus
# Processing Record 45 of Set 12 | aguas vermelhas
# Processing Record 46 of Set 12 | sakakah
# Processing Record 47 of Set 12 | rajauri
# Processing Record 48 of Set 12 | uspenka
# Processing Record 49 of Set 12 | klaksvik
# Processing Record 50 of Set 12 | bajram curri
# Processing Record 1 of Set 13 | ostrovnoy
# Processing Record 2 of Set 13 | rovaniemi
# Processing Record 3 of Set 13 | smiltene
# Processing Record 4 of Set 13 | rusape
# Processing Record 5 of Set 13 | dale
# Processing Record 6 of Set 13 | porto torres
# Processing Record 7 of Set 13 | kapustin yar
# Processing Record 8 of Set 13 | unye
# City not found. Skipping...
# Processing Record 9 of Set 13 | puno
# Processing Record 10 of Set 13 | cockburn harbour
# City not found. Skipping...
# Processing Record 11 of Set 13 | antalaha
# Processing Record 12 of Set 13 | bulri
# Processing Record 13 of Set 13 | sainte-marie
# Processing Record 14 of Set 13 | barkhan
# Processing Record 15 of Set 13 | casablanca
# Processing Record 16 of Set 13 | awbari
# Processing Record 17 of Set 13 | zelenogradsk
# Processing Record 18 of Set 13 | sant julia de loria
# Processing Record 19 of Set 13 | enugu
# Processing Record 20 of Set 13 | schererville
# Processing Record 21 of Set 13 | osakarovka
# Processing Record 22 of Set 13 | chudniv
# Processing Record 23 of Set 13 | viedma
# Processing Record 24 of Set 13 | hihya
# Processing Record 25 of Set 13 | melito di porto salvo
# Processing Record 26 of Set 13 | bredasdorp
# Processing Record 27 of Set 13 | chuy
# Processing Record 28 of Set 13 | san esteban
# Processing Record 29 of Set 13 | ushuaia
# Processing Record 30 of Set 13 | dekoa
# City not found. Skipping...
# Processing Record 31 of Set 13 | shadegan
# Processing Record 32 of Set 13 | vigrestad
# Processing Record 33 of Set 13 | port-cartier
# Processing Record 34 of Set 13 | vasto
# Processing Record 35 of Set 13 | itarema
# Processing Record 36 of Set 13 | pirmasens
# Processing Record 37 of Set 13 | ozinki
# Processing Record 38 of Set 13 | logrono
# Processing Record 39 of Set 13 | westerland
# Processing Record 40 of Set 13 | the valley
# Processing Record 41 of Set 13 | danville
# Processing Record 42 of Set 13 | tsybli
# Processing Record 43 of Set 13 | beruni
# City not found. Skipping...
# Processing Record 44 of Set 13 | merke
# Processing Record 45 of Set 13 | ayios kirikos
# City not found. Skipping...
# Processing Record 46 of Set 13 | guiglo
# Processing Record 47 of Set 13 | gazni
# City not found. Skipping...
# Processing Record 48 of Set 13 | akdepe
# Processing Record 49 of Set 13 | ancud
# Processing Record 50 of Set 13 | matagami
# Processing Record 1 of Set 14 | burgos
# Processing Record 2 of Set 14 | navoi
# Processing Record 3 of Set 14 | severodvinsk
# Processing Record 4 of Set 14 | mithi
# Processing Record 5 of Set 14 | sabha
# Processing Record 6 of Set 14 | sirvintos
# Processing Record 7 of Set 14 | jaca
# Processing Record 8 of Set 14 | corrales
# Processing Record 9 of Set 14 | yarada
# Processing Record 10 of Set 14 | den helder
# Processing Record 11 of Set 14 | semey
# Processing Record 12 of Set 14 | turukhansk
# Processing Record 13 of Set 14 | jodar
# Processing Record 14 of Set 14 | soubre
# Processing Record 15 of Set 14 | arraial do cabo
# Processing Record 16 of Set 14 | port alfred
# Processing Record 17 of Set 14 | skeldon
# Processing Record 18 of Set 14 | atasu
# Processing Record 19 of Set 14 | polovinnoye
# Processing Record 20 of Set 14 | shafranovo
# Processing Record 21 of Set 14 | cidreira
# Processing Record 22 of Set 14 | mussomeli
# Processing Record 23 of Set 14 | russkaya polyana
# Processing Record 24 of Set 14 | coihaique
# Processing Record 25 of Set 14 | gharo
# Processing Record 26 of Set 14 | krapivinskiy
# Processing Record 27 of Set 14 | port shepstone
# Processing Record 28 of Set 14 | badarwas
# Processing Record 29 of Set 14 | kumylzhenskaya
# Processing Record 30 of Set 14 | ghorawal
# Processing Record 31 of Set 14 | urumqi
# Processing Record 32 of Set 14 | svetlogorsk
# Processing Record 33 of Set 14 | dasoguz
# Processing Record 34 of Set 14 | kuryk
# Processing Record 35 of Set 14 | nicoya
# Processing Record 36 of Set 14 | omsk
# Processing Record 37 of Set 14 | katastarion
# Processing Record 38 of Set 14 | karmana
# City not found. Skipping...
# Processing Record 39 of Set 14 | mecca
# Processing Record 40 of Set 14 | taraz
# Processing Record 41 of Set 14 | orestias
# City not found. Skipping...
# Processing Record 42 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 43 of Set 14 | sayyan
# Processing Record 44 of Set 14 | blagoveshchensk
# Processing Record 45 of Set 14 | crestview
# Processing Record 46 of Set 14 | long beach
# Processing Record 47 of Set 14 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 48 of Set 14 | moose factory
# Processing Record 49 of Set 14 | kaoma
# Processing Record 50 of Set 14 | laytown
# Processing Record 1 of Set 15 | kafue
# Processing Record 2 of Set 15 | schwerin
# Processing Record 3 of Set 15 | caravelas
# Processing Record 4 of Set 15 | panaba
# Processing Record 5 of Set 15 | mopti
# Processing Record 6 of Set 15 | weymouth
# Processing Record 7 of Set 15 | poletayevo
# Processing Record 8 of Set 15 | jashpurnagar
# Processing Record 9 of Set 15 | carahue
# Processing Record 10 of Set 15 | brigantine
# Processing Record 11 of Set 15 | pedernales
# Processing Record 12 of Set 15 | saint-philippe
# Processing Record 13 of Set 15 | camacha
# Processing Record 14 of Set 15 | zhanaozen
# Processing Record 15 of Set 15 | east london
# Processing Record 16 of Set 15 | forio
# Processing Record 17 of Set 15 | bakel
# Processing Record 18 of Set 15 | srirampur
# Processing Record 19 of Set 15 | shepetivka
# Processing Record 20 of Set 15 | husavik
# Processing Record 21 of Set 15 | aktash
# Processing Record 22 of Set 15 | antsohihy
# Processing Record 23 of Set 15 | salekhard
# Processing Record 24 of Set 15 | podgorica
# Processing Record 25 of Set 15 | verkhnyaya inta
# Processing Record 26 of Set 15 | marysville
# Processing Record 27 of Set 15 | rawson
# Processing Record 28 of Set 15 | benin
# Processing Record 29 of Set 15 | menongue
# Processing Record 30 of Set 15 | itapirapua
# Processing Record 31 of Set 15 | xacmaz
# Processing Record 32 of Set 15 | uyemskiy
# Processing Record 33 of Set 15 | mezen
# Processing Record 34 of Set 15 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 15 | guanica
# Processing Record 36 of Set 15 | sindand
# City not found. Skipping...
# Processing Record 37 of Set 15 | nalut
# Processing Record 38 of Set 15 | isilkul
# Processing Record 39 of Set 15 | asgabat
# Processing Record 40 of Set 15 | taywarah
# Processing Record 41 of Set 15 | santa lucia
# Processing Record 42 of Set 15 | rock sound
# Processing Record 43 of Set 15 | torbay
# Processing Record 44 of Set 15 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 15 | zelenoborsk
# Processing Record 46 of Set 15 | juan lacaze
# Processing Record 47 of Set 15 | araguari
# Processing Record 48 of Set 15 | gagnoa
# Processing Record 49 of Set 15 | kemi
# Processing Record 50 of Set 15 | nema
# Processing Record 1 of Set 16 | seaham
# Processing Record 2 of Set 16 | selty
# Processing Record 3 of Set 16 | marsh harbour
# Processing Record 4 of Set 16 | kollumerland
# City not found. Skipping...
# Processing Record 5 of Set 16 | shelburne
# Processing Record 6 of Set 16 | buinsk
# Processing Record 7 of Set 16 | novosheshminsk
# Processing Record 8 of Set 16 | san matias
# Processing Record 9 of Set 16 | kuhdasht
# Processing Record 10 of Set 16 | el juncal
# Processing Record 11 of Set 16 | tumannyy
# City not found. Skipping...
# Processing Record 12 of Set 16 | waounde
# Processing Record 13 of Set 16 | consett
# Processing Record 14 of Set 16 | grindavik
# Processing Record 15 of Set 16 | alekseyevskoye
# Processing Record 16 of Set 16 | alice town
# Processing Record 17 of Set 16 | kristiansund
# Processing Record 18 of Set 16 | ostersund
# Processing Record 19 of Set 16 | nova vicosa
# Processing Record 20 of Set 16 | do rud
# City not found. Skipping...
# Processing Record 21 of Set 16 | bilecik
# Processing Record 22 of Set 16 | mehamn
# Processing Record 23 of Set 16 | pangody
# Processing Record 24 of Set 16 | san rafael
# Processing Record 25 of Set 16 | cuenca
# Processing Record 26 of Set 16 | jiwani
# Processing Record 27 of Set 16 | taoudenni
# Processing Record 28 of Set 16 | floro
# Processing Record 29 of Set 16 | nantucket
# Processing Record 30 of Set 16 | greensburg
# Processing Record 31 of Set 16 | patrocinio
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 726

# %%
WeatherPy_Database = makeDF(city_data)
WeatherPy_Database
# Out:
#                City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0             Aswan      EG  24.0934  32.9070     79.30        31           2
# 1          Berlevag      NO  70.8578  29.0864     37.40        74          63
# 2    Puerto Lempira      HN  15.2667 -83.7667     76.84        89          76
# 3        Pedra Azul      BR -16.0053 -41.2972     61.88        82           0
# 4    Saint-Augustin      CA  51.2260 -58.6502     52.02        96         100
# ..              ...     ...      ...      ...       ...       ...         ...
# 721       Taoudenni      ML  22.6783  -3.9836     91.69        31           5
# 722           Floro      NO  61.5996   5.0328     55.47       100          90
# 723       Nantucket      US  41.2835 -70.0995     75.09        94           1
# 724      Greensburg      US  40.3015 -79.5389     66.61        97          75
# 725      Patrocinio      BR -18.9439 -46.9925     72.66        30           7
#
#      Wind Speed          Current Description
# 0         11.54                    clear sky
# 1          6.58                broken clouds
# 2          7.81                broken clouds
# 3          3.60                    clear sky
# 4         19.95              overcast clouds
# ..          ...                          ...
# 721       10.04                    clear sky
# 722        0.00  light intensity shower rain
# 723       10.36                    clear sky
# 724        0.00                         mist
# 725        3.06                    clear sky
#
# [726 rows x 9 columns]

# %%
WeatherPy_Database.to_csv("WeatherPy_Database.csv")
