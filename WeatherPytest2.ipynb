# %%
#https://openweathermap.org/current

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests as req
from datetime import datetime

# Import the API key.
from config import weather_api_key

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
coords = [(i,j) for i in np.random.uniform(low=-90.000, high=90.000, size=50)
          for j in np.random.uniform(low=-90.000, high=90.000, size=50)]

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for i in coords:
    print(citipy.nearest_city(i[0], i[1]).city_name,
          citipy.nearest_city(i[0], i[1]).country_code)

# %%
#cities = {(citipy.nearest_city(coordinate[0], coordinate[1]).city_name) for i in coordinates}
# Create a list for holding the cities.
lowercase = list({citipy.nearest_city(i[0], i[1]).city_name for i in coords})

# %%
# Identify the nearest city for each latitude and longitude combination.
cities = [i.capitalize() for i in lowercase]
len(cities)
# Out:
# 642

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_urls = [url + "&q=" + cities[i] for i in range(len(cities))]

# %%
city_weather = [req.get(i).json for i in city_urls]

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = req.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | Harrismith
# Processing Record 2 of Set 1 | Longonjo
# Processing Record 3 of Set 1 | Eenhana
# Processing Record 4 of Set 1 | Srinagar
# Processing Record 5 of Set 1 | Azul
# Processing Record 6 of Set 1 | Vilhena
# Processing Record 7 of Set 1 | Aegviidu
# Processing Record 8 of Set 1 | Nouadhibou
# Processing Record 9 of Set 1 | Igboho
# Processing Record 10 of Set 1 | Tallahassee
# Processing Record 11 of Set 1 | Klaipeda
# Processing Record 12 of Set 1 | Reconquista
# Processing Record 13 of Set 1 | Springbok
# Processing Record 14 of Set 1 | Hearst
# Processing Record 15 of Set 1 | Taoudenni
# Processing Record 16 of Set 1 | Sladkovo
# Processing Record 17 of Set 1 | Bell ville
# Processing Record 18 of Set 1 | Huarmey
# Processing Record 19 of Set 1 | Soma
# Processing Record 20 of Set 1 | Killybegs
# Processing Record 21 of Set 1 | Skagen
# Processing Record 22 of Set 1 | Bursol
# City not found. Skipping...
# Processing Record 23 of Set 1 | Ronne
# Processing Record 24 of Set 1 | Calvinia
# Processing Record 25 of Set 1 | Mocuba
# Processing Record 26 of Set 1 | Taolanaro
# City not found. Skipping...
# Processing Record 27 of Set 1 | Patnos
# Processing Record 28 of Set 1 | Prieska
# Processing Record 29 of Set 1 | Gualeguaychu
# Processing Record 30 of Set 1 | Ostrovnoy
# Processing Record 31 of Set 1 | Port blair
# Processing Record 32 of Set 1 | Drinovci
# Processing Record 33 of Set 1 | Leshukonskoye
# Processing Record 34 of Set 1 | Sao filipe
# Processing Record 35 of Set 1 | Lobanovo
# Processing Record 36 of Set 1 | Dubenskiy
# City not found. Skipping...
# Processing Record 37 of Set 1 | Marsh harbour
# Processing Record 38 of Set 1 | Tsentralnyy
# City not found. Skipping...
# Processing Record 39 of Set 1 | Chimbote
# Processing Record 40 of Set 1 | Matagami
# Processing Record 41 of Set 1 | Quatre cocos
# Processing Record 42 of Set 1 | Lerum
# Processing Record 43 of Set 1 | Koungou
# Processing Record 44 of Set 1 | Yefremov
# Processing Record 45 of Set 1 | Brae
# Processing Record 46 of Set 1 | Aguas vermelhas
# Processing Record 47 of Set 1 | Houma
# Processing Record 48 of Set 1 | Alta floresta
# Processing Record 49 of Set 1 | Ijui
# Processing Record 50 of Set 1 | Hadrut
# Processing Record 1 of Set 2 | Castro
# Processing Record 2 of Set 2 | Saint augustine
# Processing Record 3 of Set 2 | Igarka
# Processing Record 4 of Set 2 | Saldanha
# Processing Record 5 of Set 2 | Bayir
# Processing Record 6 of Set 2 | Zhetybay
# City not found. Skipping...
# Processing Record 7 of Set 2 | Villa carlos paz
# Processing Record 8 of Set 2 | Adrar
# Processing Record 9 of Set 2 | Halden
# Processing Record 10 of Set 2 | Pangnirtung
# Processing Record 11 of Set 2 | Leghorn
# City not found. Skipping...
# Processing Record 12 of Set 2 | Colares
# Processing Record 13 of Set 2 | Ambilobe
# Processing Record 14 of Set 2 | Tornio
# Processing Record 15 of Set 2 | Braslav
# City not found. Skipping...
# Processing Record 16 of Set 2 | Tarudant
# City not found. Skipping...
# Processing Record 17 of Set 2 | Mendoza
# Processing Record 18 of Set 2 | Ventspils
# Processing Record 19 of Set 2 | Kushmurun
# Processing Record 20 of Set 2 | Berlevag
# Processing Record 21 of Set 2 | Kaman
# Processing Record 22 of Set 2 | Nkhotakota
# Processing Record 23 of Set 2 | Emirdag
# Processing Record 24 of Set 2 | Leh
# Processing Record 25 of Set 2 | Carazinho
# Processing Record 26 of Set 2 | Torbay
# Processing Record 27 of Set 2 | Muros
# Processing Record 28 of Set 2 | Ponta do sol
# Processing Record 29 of Set 2 | Uyemskiy
# Processing Record 30 of Set 2 | Skagastrond
# City not found. Skipping...
# Processing Record 31 of Set 2 | Pliska
# Processing Record 32 of Set 2 | Loncoche
# Processing Record 33 of Set 2 | Bonavista
# Processing Record 34 of Set 2 | Perevoz
# Processing Record 35 of Set 2 | Malakal
# Processing Record 36 of Set 2 | Antsohihy
# Processing Record 37 of Set 2 | Amderma
# City not found. Skipping...
# Processing Record 38 of Set 2 | Azimur
# City not found. Skipping...
# Processing Record 39 of Set 2 | Havelock
# Processing Record 40 of Set 2 | Jaisalmer
# Processing Record 41 of Set 2 | Blue ash
# Processing Record 42 of Set 2 | Ler
# Processing Record 43 of Set 2 | Saint-pierre
# Processing Record 44 of Set 2 | Kamenka
# Processing Record 45 of Set 2 | Urumqi
# Processing Record 46 of Set 2 | Jumla
# Processing Record 47 of Set 2 | Saint-joseph
# Processing Record 48 of Set 2 | Haradok
# Processing Record 49 of Set 2 | Grand river south east
# City not found. Skipping...
# Processing Record 50 of Set 2 | San rafael
# Processing Record 1 of Set 3 | Attawapiskat
# City not found. Skipping...
# Processing Record 2 of Set 3 | Mansfield
# Processing Record 3 of Set 3 | Yurga
# Processing Record 4 of Set 3 | The valley
# Processing Record 5 of Set 3 | Chicama
# Processing Record 6 of Set 3 | Fene
# Processing Record 7 of Set 3 | Ejido
# Processing Record 8 of Set 3 | Campo maior
# Processing Record 9 of Set 3 | Sioux lookout
# Processing Record 10 of Set 3 | Lubango
# Processing Record 11 of Set 3 | Stornoway
# Processing Record 12 of Set 3 | Fomboni
# Processing Record 13 of Set 3 | Tobol
# Processing Record 14 of Set 3 | Maceio
# Processing Record 15 of Set 3 | Porto nacional
# Processing Record 16 of Set 3 | Plettenberg bay
# Processing Record 17 of Set 3 | Iberia
# Processing Record 18 of Set 3 | Mirabad
# Processing Record 19 of Set 3 | Blantyre
# Processing Record 20 of Set 3 | Olafsvik
# Processing Record 21 of Set 3 | Salinopolis
# Processing Record 22 of Set 3 | Kadoma
# Processing Record 23 of Set 3 | Valga
# Processing Record 24 of Set 3 | Korsor
# Processing Record 25 of Set 3 | Husavik
# Processing Record 26 of Set 3 | Tamandare
# Processing Record 27 of Set 3 | Laguna
# Processing Record 28 of Set 3 | Victoria
# Processing Record 29 of Set 3 | Viedma
# Processing Record 30 of Set 3 | Abha
# Processing Record 31 of Set 3 | Kokkola
# Processing Record 32 of Set 3 | Kiruna
# Processing Record 33 of Set 3 | East london
# Processing Record 34 of Set 3 | Togur
# Processing Record 35 of Set 3 | Kubinka
# Processing Record 36 of Set 3 | Aracaju
# Processing Record 37 of Set 3 | Mollendo
# Processing Record 38 of Set 3 | Mitsamiouli
# Processing Record 39 of Set 3 | Aakirkeby
# City not found. Skipping...
# Processing Record 40 of Set 3 | Carnarvon
# Processing Record 41 of Set 3 | Redcar
# Processing Record 42 of Set 3 | Koumra
# Processing Record 43 of Set 3 | Dabakala
# Processing Record 44 of Set 3 | Umm lajj
# Processing Record 45 of Set 3 | Valdosta
# Processing Record 46 of Set 3 | Vypolzovo
# Processing Record 47 of Set 3 | Vengerovo
# Processing Record 48 of Set 3 | Mecca
# Processing Record 49 of Set 3 | Johi
# Processing Record 50 of Set 3 | Naklo nad notecia
# Processing Record 1 of Set 4 | Beloha
# Processing Record 2 of Set 4 | Kegayli
# City not found. Skipping...
# Processing Record 3 of Set 4 | Kemijarvi
# Processing Record 4 of Set 4 | Ubinskoye
# Processing Record 5 of Set 4 | Vorozhba
# Processing Record 6 of Set 4 | Shumerlya
# Processing Record 7 of Set 4 | Belushya guba
# City not found. Skipping...
# Processing Record 8 of Set 4 | Glushkovo
# Processing Record 9 of Set 4 | Loralai
# Processing Record 10 of Set 4 | Aksu
# Processing Record 11 of Set 4 | San ramon
# Processing Record 12 of Set 4 | Veseloyarsk
# Processing Record 13 of Set 4 | Illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 4 | New london
# Processing Record 15 of Set 4 | Slantsy
# Processing Record 16 of Set 4 | Dolores
# Processing Record 17 of Set 4 | Sheregesh
# Processing Record 18 of Set 4 | Umea
# Processing Record 19 of Set 4 | Beaver dam
# Processing Record 20 of Set 4 | Makushino
# Processing Record 21 of Set 4 | Gerash
# Processing Record 22 of Set 4 | Surt
# Processing Record 23 of Set 4 | Maragogi
# Processing Record 24 of Set 4 | Bud
# Processing Record 25 of Set 4 | Saint-maximin-la-sainte-baume
# Processing Record 26 of Set 4 | Carndonagh
# Processing Record 27 of Set 4 | Vila franca do campo
# Processing Record 28 of Set 4 | Pisco
# Processing Record 29 of Set 4 | Krasnoarmeysk
# Processing Record 30 of Set 4 | Bolungarvik
# City not found. Skipping...
# Processing Record 31 of Set 4 | Port-cartier
# Processing Record 32 of Set 4 | Turbat
# Processing Record 33 of Set 4 | Carbonia
# Processing Record 34 of Set 4 | Gorakhpur
# Processing Record 35 of Set 4 | Paamiut
# Processing Record 36 of Set 4 | Hakvik
# City not found. Skipping...
# Processing Record 37 of Set 4 | Barinitas
# Processing Record 38 of Set 4 | Mendeleyevsk
# Processing Record 39 of Set 4 | Ormara
# Processing Record 40 of Set 4 | Barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 4 | Sosva
# Processing Record 42 of Set 4 | Derzhavinsk
# Processing Record 43 of Set 4 | Irece
# Processing Record 44 of Set 4 | Mutsamudu
# City not found. Skipping...
# Processing Record 45 of Set 4 | Bella union
# Processing Record 46 of Set 4 | Caceres
# Processing Record 47 of Set 4 | Elizabeth city
# Processing Record 48 of Set 4 | Staffanstorp
# Processing Record 49 of Set 4 | Bandarbeyla
# Processing Record 50 of Set 4 | Gat
# Processing Record 1 of Set 5 | Vikevag
# Processing Record 2 of Set 5 | Krasnoselkup
# Processing Record 3 of Set 5 | Road town
# Processing Record 4 of Set 5 | Nanortalik
# Processing Record 5 of Set 5 | Deogarh
# Processing Record 6 of Set 5 | Brasileia
# Processing Record 7 of Set 5 | Puerto quijarro
# Processing Record 8 of Set 5 | Ulagan
# Processing Record 9 of Set 5 | Santa rosa
# Processing Record 10 of Set 5 | Iqaluit
# Processing Record 11 of Set 5 | Chugunash
# City not found. Skipping...
# Processing Record 12 of Set 5 | Tuggurt
# City not found. Skipping...
# Processing Record 13 of Set 5 | Chinsali
# Processing Record 14 of Set 5 | Belyye berega
# Processing Record 15 of Set 5 | Itapuranga
# Processing Record 16 of Set 5 | Lagoa vermelha
# Processing Record 17 of Set 5 | Deori
# Processing Record 18 of Set 5 | Marv dasht
# City not found. Skipping...
# Processing Record 19 of Set 5 | Kleck
# City not found. Skipping...
# Processing Record 20 of Set 5 | Tumannyy
# City not found. Skipping...
# Processing Record 21 of Set 5 | Zlobin
# Processing Record 22 of Set 5 | Ocher
# Processing Record 23 of Set 5 | Rokytne
# Processing Record 24 of Set 5 | Pavda
# City not found. Skipping...
# Processing Record 25 of Set 5 | Lima
# Processing Record 26 of Set 5 | Jalu
# Processing Record 27 of Set 5 | Parvatsar
# Processing Record 28 of Set 5 | Ullapool
# Processing Record 29 of Set 5 | Mount pleasant
# Processing Record 30 of Set 5 | Druzhba
# Processing Record 31 of Set 5 | Tazovskiy
# Processing Record 32 of Set 5 | Santa cruz de la palma
# Processing Record 33 of Set 5 | Pimenta bueno
# Processing Record 34 of Set 5 | Raudeberg
# Processing Record 35 of Set 5 | Bridlington
# Processing Record 36 of Set 5 | Saint anthony
# Processing Record 37 of Set 5 | Arkhangelsk
# Processing Record 38 of Set 5 | Donji komren
# City not found. Skipping...
# Processing Record 39 of Set 5 | Kantunilkin
# Processing Record 40 of Set 5 | Shaturtorf
# Processing Record 41 of Set 5 | General pico
# Processing Record 42 of Set 5 | Busselton
# Processing Record 43 of Set 5 | Ushuaia
# Processing Record 44 of Set 5 | Clyde river
# Processing Record 45 of Set 5 | Sharlyk
# Processing Record 46 of Set 5 | Bambous virieux
# Processing Record 47 of Set 5 | Zapolyarnyy
# Processing Record 48 of Set 5 | Punta de bombon
# Processing Record 49 of Set 5 | Ashitkovo
# Processing Record 50 of Set 5 | Kuusamo
# Processing Record 1 of Set 6 | Kulu
# Processing Record 2 of Set 6 | Graaff-reinet
# Processing Record 3 of Set 6 | Jiddah
# City not found. Skipping...
# Processing Record 4 of Set 6 | Sistranda
# Processing Record 5 of Set 6 | Warmbad
# Processing Record 6 of Set 6 | Aswan
# Processing Record 7 of Set 6 | Pervomayskoye
# Processing Record 8 of Set 6 | Chulym
# Processing Record 9 of Set 6 | Dolbeau
# City not found. Skipping...
# Processing Record 10 of Set 6 | Loukhi
# Processing Record 11 of Set 6 | Cap malheureux
# Processing Record 12 of Set 6 | Lyngseidet
# Processing Record 13 of Set 6 | Valdivia
# Processing Record 14 of Set 6 | Mrirt
# City not found. Skipping...
# Processing Record 15 of Set 6 | Bredasdorp
# Processing Record 16 of Set 6 | Mabaruma
# Processing Record 17 of Set 6 | Nyimba
# Processing Record 18 of Set 6 | Lemesos
# City not found. Skipping...
# Processing Record 19 of Set 6 | Mufumbwe
# Processing Record 20 of Set 6 | Nakambala
# Processing Record 21 of Set 6 | Disna
# Processing Record 22 of Set 6 | San martin
# Processing Record 23 of Set 6 | Nepa nagar
# Processing Record 24 of Set 6 | Imbituba
# Processing Record 25 of Set 6 | Odweyne
# Processing Record 26 of Set 6 | Formosa
# Processing Record 27 of Set 6 | Havre-saint-pierre
# Processing Record 28 of Set 6 | Cayenne
# Processing Record 29 of Set 6 | Karpogory
# Processing Record 30 of Set 6 | Bodo
# Processing Record 31 of Set 6 | Bela
# Processing Record 32 of Set 6 | Belmonte
# Processing Record 33 of Set 6 | Luau
# Processing Record 34 of Set 6 | Severodvinsk
# Processing Record 35 of Set 6 | Birjand
# Processing Record 36 of Set 6 | Cordoba
# Processing Record 37 of Set 6 | Mwanza
# Processing Record 38 of Set 6 | Krasnyy yar
# Processing Record 39 of Set 6 | Balkanabat
# Processing Record 40 of Set 6 | Chapais
# Processing Record 41 of Set 6 | Gualeguay
# Processing Record 42 of Set 6 | Holoby
# Processing Record 43 of Set 6 | Mineiros
# Processing Record 44 of Set 6 | Hermanus
# Processing Record 45 of Set 6 | Bengkulu
# Processing Record 46 of Set 6 | Vicuna
# Processing Record 47 of Set 6 | Winschoten
# Processing Record 48 of Set 6 | Mahajanga
# Processing Record 49 of Set 6 | Maykain
# City not found. Skipping...
# Processing Record 50 of Set 6 | Port hawkesbury
# Processing Record 1 of Set 7 | Neyvo-shaytanskiy
# Processing Record 2 of Set 7 | Longyearbyen
# Processing Record 3 of Set 7 | Tolstoy-yurt
# Processing Record 4 of Set 7 | Aguimes
# Processing Record 5 of Set 7 | San jose
# Processing Record 6 of Set 7 | Benguela
# Processing Record 7 of Set 7 | Sidi qasim
# City not found. Skipping...
# Processing Record 8 of Set 7 | Gagra
# Processing Record 9 of Set 7 | Bahia blanca
# Processing Record 10 of Set 7 | Karaul
# City not found. Skipping...
# Processing Record 11 of Set 7 | Hong
# Processing Record 12 of Set 7 | Grindavik
# Processing Record 13 of Set 7 | Tchamba
# Processing Record 14 of Set 7 | Skegness
# Processing Record 15 of Set 7 | Pascagoula
# Processing Record 16 of Set 7 | Bathsheba
# Processing Record 17 of Set 7 | Dingle
# Processing Record 18 of Set 7 | Grand gaube
# Processing Record 19 of Set 7 | Shchelyayur
# City not found. Skipping...
# Processing Record 20 of Set 7 | Dhankuta
# Processing Record 21 of Set 7 | Urcos
# Processing Record 22 of Set 7 | Tyukhtet
# Processing Record 23 of Set 7 | Port alfred
# Processing Record 24 of Set 7 | Riyadh
# Processing Record 25 of Set 7 | Rorvik
# Processing Record 26 of Set 7 | Salvador
# Processing Record 27 of Set 7 | Ambodifototra
# City not found. Skipping...
# Processing Record 28 of Set 7 | Mwinilunga
# Processing Record 29 of Set 7 | Faya
# Processing Record 30 of Set 7 | Artigas
# Processing Record 31 of Set 7 | Mutoko
# Processing Record 32 of Set 7 | Teeli
# Processing Record 33 of Set 7 | Gazanjyk
# Processing Record 34 of Set 7 | Iskateley
# Processing Record 35 of Set 7 | Ziarat
# Processing Record 36 of Set 7 | Sechura
# Processing Record 37 of Set 7 | Matay
# Processing Record 38 of Set 7 | Vestmanna
# Processing Record 39 of Set 7 | Umzimvubu
# City not found. Skipping...
# Processing Record 40 of Set 7 | Ponto novo
# Processing Record 41 of Set 7 | Sahbuz
# Processing Record 42 of Set 7 | Oruro
# Processing Record 43 of Set 7 | Loans
# Processing Record 44 of Set 7 | Sumkino
# Processing Record 45 of Set 7 | Nuuk
# Processing Record 46 of Set 7 | Kalevala
# Processing Record 47 of Set 7 | Bardiyah
# Processing Record 48 of Set 7 | Aflu
# City not found. Skipping...
# Processing Record 49 of Set 7 | Waddan
# Processing Record 50 of Set 7 | Herat
# Processing Record 1 of Set 8 | Itapirapua
# Processing Record 2 of Set 8 | Berezniki
# Processing Record 3 of Set 8 | Rolim de moura
# City not found. Skipping...
# Processing Record 4 of Set 8 | Aksarka
# Processing Record 5 of Set 8 | Ponta delgada
# Processing Record 6 of Set 8 | Mahebourg
# Processing Record 7 of Set 8 | Bandrele
# Processing Record 8 of Set 8 | Dzaoudzi
# Processing Record 9 of Set 8 | Parrita
# Processing Record 10 of Set 8 | Pervomayskaya
# Processing Record 11 of Set 8 | Vestmannaeyjar
# Processing Record 12 of Set 8 | Seydi
# Processing Record 13 of Set 8 | Los llanos de aridane
# Processing Record 14 of Set 8 | Hualmay
# Processing Record 15 of Set 8 | Przasnysz
# Processing Record 16 of Set 8 | Sakakah
# Processing Record 17 of Set 8 | Santa comba
# Processing Record 18 of Set 8 | Malaut
# Processing Record 19 of Set 8 | Marawi
# Processing Record 20 of Set 8 | Terre haute
# Processing Record 21 of Set 8 | Dalvik
# Processing Record 22 of Set 8 | Buraydah
# Processing Record 23 of Set 8 | Atlantic city
# Processing Record 24 of Set 8 | Georgetown
# Processing Record 25 of Set 8 | Cidreira
# Processing Record 26 of Set 8 | Valparaiso
# Processing Record 27 of Set 8 | Kavaratti
# Processing Record 28 of Set 8 | Gorodishche
# Processing Record 29 of Set 8 | Comodoro rivadavia
# Processing Record 30 of Set 8 | Conde
# Processing Record 31 of Set 8 | Roald
# Processing Record 32 of Set 8 | Novodugino
# Processing Record 33 of Set 8 | Karlskrona
# Processing Record 34 of Set 8 | Vokhma
# Processing Record 35 of Set 8 | Edgemere
# Processing Record 36 of Set 8 | Rodrigues alves
# Processing Record 37 of Set 8 | Lyuban
# Processing Record 38 of Set 8 | Praia da vitoria
# Processing Record 39 of Set 8 | Keffi
# Processing Record 40 of Set 8 | Chuy
# Processing Record 41 of Set 8 | Usinsk
# Processing Record 42 of Set 8 | Parga
# Processing Record 43 of Set 8 | Rio grande
# Processing Record 44 of Set 8 | Alappuzha
# Processing Record 45 of Set 8 | San carlos de bariloche
# Processing Record 46 of Set 8 | Malazgirt
# Processing Record 47 of Set 8 | Sorland
# Processing Record 48 of Set 8 | Shihezi
# Processing Record 49 of Set 8 | Canterbury
# Processing Record 50 of Set 8 | Svetlogorsk
# Processing Record 1 of Set 9 | Zarautz
# Processing Record 2 of Set 9 | Urgut
# Processing Record 3 of Set 9 | Ulundi
# Processing Record 4 of Set 9 | Zabol
# Processing Record 5 of Set 9 | Kyle of lochalsh
# City not found. Skipping...
# Processing Record 6 of Set 9 | Qaanaaq
# Processing Record 7 of Set 9 | Bogoslovka
# Processing Record 8 of Set 9 | Yurla
# Processing Record 9 of Set 9 | Angoche
# Processing Record 10 of Set 9 | Raga
# Processing Record 11 of Set 9 | Mozarlandia
# Processing Record 12 of Set 9 | Utinga
# Processing Record 13 of Set 9 | Ribeira grande
# Processing Record 14 of Set 9 | Abu kamal
# Processing Record 15 of Set 9 | Sahrak
# City not found. Skipping...
# Processing Record 16 of Set 9 | Sept-iles
# Processing Record 17 of Set 9 | Pangody
# Processing Record 18 of Set 9 | Ornskoldsvik
# Processing Record 19 of Set 9 | Great yarmouth
# Processing Record 20 of Set 9 | Veendam
# Processing Record 21 of Set 9 | Quelimane
# Processing Record 22 of Set 9 | Georgiyevka
# Processing Record 23 of Set 9 | Bubaque
# Processing Record 24 of Set 9 | Mezen
# Processing Record 25 of Set 9 | Gedo
# Processing Record 26 of Set 9 | Verkhnyaya inta
# Processing Record 27 of Set 9 | Joshimath
# Processing Record 28 of Set 9 | Warqla
# City not found. Skipping...
# Processing Record 29 of Set 9 | Den helder
# Processing Record 30 of Set 9 | Kandiari
# Processing Record 31 of Set 9 | Lunsar
# Processing Record 32 of Set 9 | Kalabo
# Processing Record 33 of Set 9 | Ascension
# Processing Record 34 of Set 9 | Villaviciosa
# Processing Record 35 of Set 9 | Verkhniy uslon
# Processing Record 36 of Set 9 | Beterou
# Processing Record 37 of Set 9 | Praia
# Processing Record 38 of Set 9 | San bartolome de tirajana
# Processing Record 39 of Set 9 | Diamantina
# Processing Record 40 of Set 9 | Masallatah
# Processing Record 41 of Set 9 | Namibe
# Processing Record 42 of Set 9 | Kruisfontein
# Processing Record 43 of Set 9 | Maldonado
# Processing Record 44 of Set 9 | Duvan
# Processing Record 45 of Set 9 | Rafsanjan
# Processing Record 46 of Set 9 | Karakendzha
# City not found. Skipping...
# Processing Record 47 of Set 9 | Shuyskoye
# Processing Record 48 of Set 9 | Pavlovka
# Processing Record 49 of Set 9 | Azrow
# City not found. Skipping...
# Processing Record 50 of Set 9 | Shelburne
# Processing Record 1 of Set 10 | Coruripe
# Processing Record 2 of Set 10 | Pilna
# Processing Record 3 of Set 10 | Westport
# Processing Record 4 of Set 10 | Sol-iletsk
# Processing Record 5 of Set 10 | Doha
# Processing Record 6 of Set 10 | Coquimbo
# Processing Record 7 of Set 10 | Kpandae
# Processing Record 8 of Set 10 | Qaqortoq
# Processing Record 9 of Set 10 | Lockport
# Processing Record 10 of Set 10 | Codrington
# Processing Record 11 of Set 10 | Tselinnoye
# Processing Record 12 of Set 10 | Barra do bugres
# Processing Record 13 of Set 10 | Naryan-mar
# Processing Record 14 of Set 10 | Vila velha
# Processing Record 15 of Set 10 | Lebyazhye
# Processing Record 16 of Set 10 | Stara vyzhivka
# Processing Record 17 of Set 10 | Mala
# Processing Record 18 of Set 10 | Ust-tsilma
# Processing Record 19 of Set 10 | Antalaha
# Processing Record 20 of Set 10 | Honningsvag
# Processing Record 21 of Set 10 | Salekhard
# Processing Record 22 of Set 10 | Zachagansk
# City not found. Skipping...
# Processing Record 23 of Set 10 | Karauzyak
# City not found. Skipping...
# Processing Record 24 of Set 10 | Xai-xai
# Processing Record 25 of Set 10 | Kitchener
# Processing Record 26 of Set 10 | Skelleftea
# Processing Record 27 of Set 10 | Saint george
# Processing Record 28 of Set 10 | Ongandjera
# Processing Record 29 of Set 10 | Nantucket
# Processing Record 30 of Set 10 | Kuytun
# Processing Record 31 of Set 10 | Ouadda
# Processing Record 32 of Set 10 | Oulu
# Processing Record 33 of Set 10 | Hithadhoo
# Processing Record 34 of Set 10 | Padang
# Processing Record 35 of Set 10 | Camacha
# Processing Record 36 of Set 10 | Kannauj
# Processing Record 37 of Set 10 | Sinop
# Processing Record 38 of Set 10 | Klaksvik
# Processing Record 39 of Set 10 | Dianopolis
# City not found. Skipping...
# Processing Record 40 of Set 10 | Chilca
# Processing Record 41 of Set 10 | Ondarroa
# Processing Record 42 of Set 10 | Arlit
# Processing Record 43 of Set 10 | Oranjemund
# Processing Record 44 of Set 10 | Kilrush
# Processing Record 45 of Set 10 | Buritis
# Processing Record 46 of Set 10 | Salym
# Processing Record 47 of Set 10 | Vallenar
# Processing Record 48 of Set 10 | Novyy urengoy
# Processing Record 49 of Set 10 | Lebu
# Processing Record 50 of Set 10 | Morrinhos
# Processing Record 1 of Set 11 | Tasbuget
# City not found. Skipping...
# Processing Record 2 of Set 11 | Oster
# Processing Record 3 of Set 11 | Barra do garcas
# Processing Record 4 of Set 11 | Mehamn
# Processing Record 5 of Set 11 | Velizh
# Processing Record 6 of Set 11 | Mar del plata
# Processing Record 7 of Set 11 | Upernavik
# Processing Record 8 of Set 11 | Izhma
# Processing Record 9 of Set 11 | Gornoye loo
# Processing Record 10 of Set 11 | Shakawe
# Processing Record 11 of Set 11 | Tarata
# Processing Record 12 of Set 11 | Nanuque
# Processing Record 13 of Set 11 | Saint-augustin
# Processing Record 14 of Set 11 | Butterworth
# Processing Record 15 of Set 11 | Cape town
# Processing Record 16 of Set 11 | Tukrah
# Processing Record 17 of Set 11 | Korla
# Processing Record 18 of Set 11 | Dhidhdhoo
# Processing Record 19 of Set 11 | Nueve de julio
# Processing Record 20 of Set 11 | Awbari
# Processing Record 21 of Set 11 | Sorata
# Processing Record 22 of Set 11 | Lulea
# Processing Record 23 of Set 11 | Touba
# Processing Record 24 of Set 11 | Sao joao da barra
# Processing Record 25 of Set 11 | Maksatikha
# Processing Record 26 of Set 11 | Richards bay
# Processing Record 27 of Set 11 | Cuamba
# Processing Record 28 of Set 11 | Ust-tarka
# Processing Record 29 of Set 11 | Blagoyevo
# Processing Record 30 of Set 11 | Chingirlau
# Processing Record 31 of Set 11 | Lagoa
# Processing Record 32 of Set 11 | Urengoy
# Processing Record 33 of Set 11 | Cazaje
# City not found. Skipping...
# Processing Record 34 of Set 11 | Hofn
# Processing Record 35 of Set 11 | Rocha
# Processing Record 36 of Set 11 | Janauba
# Processing Record 37 of Set 11 | Zhanaozen
# Processing Record 38 of Set 11 | Karaidel
# Processing Record 39 of Set 11 | Kolyvan
# Processing Record 40 of Set 11 | Moa
# Processing Record 41 of Set 11 | Barabinsk
# Processing Record 42 of Set 11 | Dyurtyuli
# Processing Record 43 of Set 11 | Ilulissat
# Processing Record 44 of Set 11 | Saint-philippe
# Processing Record 45 of Set 11 | Sao francisco
# Processing Record 46 of Set 11 | Dikson
# Processing Record 47 of Set 11 | Santa lucia
# Processing Record 48 of Set 11 | Marcona
# City not found. Skipping...
# Processing Record 49 of Set 11 | Yar-sale
# Processing Record 50 of Set 11 | Rome
# Processing Record 1 of Set 12 | Chillicothe
# Processing Record 2 of Set 12 | Prado
# Processing Record 3 of Set 12 | Luderitz
# Processing Record 4 of Set 12 | Richmond
# Processing Record 5 of Set 12 | Nizhniye vyazovyye
# Processing Record 6 of Set 12 | Ibra
# Processing Record 7 of Set 12 | Punta arenas
# Processing Record 8 of Set 12 | Kashi
# Processing Record 9 of Set 12 | Ainazi
# Processing Record 10 of Set 12 | Moose factory
# Processing Record 11 of Set 12 | Sao desiderio
# Processing Record 12 of Set 12 | Lafiagi
# Processing Record 13 of Set 12 | Tessalit
# Processing Record 14 of Set 12 | Brzeg dolny
# Processing Record 15 of Set 12 | Correntina
# Processing Record 16 of Set 12 | Lukiv
# Processing Record 17 of Set 12 | Vardo
# Processing Record 18 of Set 12 | Tatarsk
# Processing Record 19 of Set 12 | Narsaq
# Processing Record 20 of Set 12 | Sivas
# Processing Record 21 of Set 12 | Wilmington
# Processing Record 22 of Set 12 | Hauterive
# Processing Record 23 of Set 12 | Carutapera
# Processing Record 24 of Set 12 | Bilma
# Processing Record 25 of Set 12 | Berdyuzhye
# City not found. Skipping...
# Processing Record 26 of Set 12 | Svetlyy
# Processing Record 27 of Set 12 | Havoysund
# Processing Record 28 of Set 12 | Tupelo
# Processing Record 29 of Set 12 | Jalalabad
# Processing Record 30 of Set 12 | Hamilton
# Processing Record 31 of Set 12 | Sao jose da coroa grande
# Processing Record 32 of Set 12 | Kajaani
# Processing Record 33 of Set 12 | Tabory
# Processing Record 34 of Set 12 | Parana
# Processing Record 35 of Set 12 | Arraial do cabo
# Processing Record 36 of Set 12 | Virginia beach
# Processing Record 37 of Set 12 | Stykkisholmur
# Processing Record 38 of Set 12 | Coihaique
# Processing Record 39 of Set 12 | Blonduos
# City not found. Skipping...
# Processing Record 40 of Set 12 | Khargone
# Processing Record 41 of Set 12 | Ancud
# Processing Record 42 of Set 12 | Itarema
# Processing Record 43 of Set 12 | La ligua
# Processing Record 44 of Set 12 | Kozhva
# Processing Record 45 of Set 12 | Qasigiannguit
# Processing Record 46 of Set 12 | Tineo
# Processing Record 47 of Set 12 | Pavlovskiy
# Processing Record 48 of Set 12 | Maniitsoq
# Processing Record 49 of Set 12 | Sorvag
# City not found. Skipping...
# Processing Record 50 of Set 12 | Novobirilyussy
# Processing Record 1 of Set 13 | Harsin
# Processing Record 2 of Set 13 | Fritzlar
# Processing Record 3 of Set 13 | Sambava
# Processing Record 4 of Set 13 | Margate
# Processing Record 5 of Set 13 | Jequie
# Processing Record 6 of Set 13 | Port elizabeth
# Processing Record 7 of Set 13 | Sucre
# Processing Record 8 of Set 13 | Pinega
# Processing Record 9 of Set 13 | Dubrovka
# Processing Record 10 of Set 13 | Khapa
# Processing Record 11 of Set 13 | Gloversville
# Processing Record 12 of Set 13 | Risalpur
# Processing Record 13 of Set 13 | Storforshei
# Processing Record 14 of Set 13 | Trinidad
# Processing Record 15 of Set 13 | Souillac
# Processing Record 16 of Set 13 | Talnakh
# Processing Record 17 of Set 13 | Jamestown
# Processing Record 18 of Set 13 | Rebrikha
# Processing Record 19 of Set 13 | Sedelnikovo
# City not found. Skipping...
# Processing Record 20 of Set 13 | Abnub
# Processing Record 21 of Set 13 | Nexo
# Processing Record 22 of Set 13 | Rio branco
# Processing Record 23 of Set 13 | Cauquenes
# Processing Record 24 of Set 13 | Esik
# Processing Record 25 of Set 13 | Konstantinovskiy
# Processing Record 26 of Set 13 | Oksbol
# Processing Record 27 of Set 13 | Stokmarknes
# Processing Record 28 of Set 13 | Rajpipla
# Processing Record 29 of Set 13 | Cockburn town
# Processing Record 30 of Set 13 | Necochea
# Processing Record 31 of Set 13 | Sur
# Processing Record 32 of Set 13 | Aprelevka
# Processing Record 33 of Set 13 | Sisimiut
# Processing Record 34 of Set 13 | Gort
# Processing Record 35 of Set 13 | Tasiilaq
# Processing Record 36 of Set 13 | Letterkenny
# Processing Record 37 of Set 13 | Tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 13 | Winburg
# Processing Record 39 of Set 13 | Isla mujeres
# Processing Record 40 of Set 13 | Kedrovyy
# Processing Record 41 of Set 13 | Freeport
# Processing Record 42 of Set 13 | Dalbandin
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data = []
city_weather = req.get(city_urls[0]).json()
city_lat = city_weather["coord"]["lat"]
city_lng = city_weather["coord"]["lon"]
city_max_temp = city_weather["main"]["temp_max"]
city_humidity = city_weather["main"]["humidity"]
city_clouds = city_weather["clouds"]["all"]
city_wind = city_weather["wind"]["speed"]
city_country = city_weather["sys"]["country"]
# Convert the date to ISO standard.
city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
# Append the city information into city_data list.
city_data.append({"City": cities[0].title(),
                  "Lat": city_lat,
                  "Lng": city_lng,
                  "Max Temp": city_max_temp,
                  "Humidity": city_humidity,
                  "Cloudiness": city_clouds,
                  "Wind Speed": city_wind,
                  "Country": city_country,
                  "Date": city_date})

# %%
city_data
# Out:
# [{'City': 'Harrismith',
#   'Lat': -28.2728,
#   'Lng': 29.1295,
#   'Max Temp': 46.78,
#   'Humidity': 73,
#   'Cloudiness': 1,
#   'Wind Speed': 1.97,
#   'Country': 'ZA',
#   'Date': '2021-09-10 01:17:58'}]

# %%
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = req.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")

# %%
len(city_data)
